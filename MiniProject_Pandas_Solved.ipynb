# %% [markdown]
# # **PANDAS MINI PROJECT**

# %% [markdown]
# You are a data analyst at a university tasked with analyzing the grades of students in a course. Your goal is to provide insights into the performance of students, identify patterns, and make recommendations for improving student outcomes. You will use Python, Pandas, and Numpy to load, clean, and analyze the data where appropriate

# %%
#load the libraries
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#load the roster file and display first 5 rows
roster_file = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/roster.csv')

roster_file.rename(columns={'Email Address': 'Email'}, inplace=True)
NetID = roster_file['NetID'].str.lower()
roster_file.head(5)
# Out:
#         ID                    Name     NetID                      Email  \
# 0  1234567      Barrera Jr., Woody  WXB12345  WOODY.BARRERA_JR@UNIV.EDU
# 1  2345678        Lambert, Malaika  MXL12345   MALAIKA.LAMBERT@UNIV.EDU
# 2  3456789            Joyce, Traci  TXJ12345       TRACI.JOYCE@UNIV.EDU
# 3  4567890      Flower, John Gregg  JGF12345   JOHN.G.2.FLOWER@UNIV.EDU
# 4  8406082  Johnson, Stacy Michael  SMJ00936     STACY.JOHNSON@UNIV.EDU
#
#    Section
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2

# %% [markdown]
# Eh? This is not the data that we want :( We want to have it more modified.

# %% [markdown]
#   We want the 'roster' to be something else! How though:
#
#   We want **NetID**, **Email Address** and **Section** but somehow different:
#
#   1. NetID: make the each string in lowercase and have it set as an index.
#   2. Email Address: have the string in lowercase
#
#   and after that, have these 3 columns display in a dataframe.

# %%
#data pre-processing
roster_file['NetID'] = roster_file['NetID'].str.lower()
roster_file['Email'] = roster_file['Email'].str.lower()
roster_file.set_index('NetID', inplace=True)
roster_transformed_columns = roster_file[['Email', 'Section']]
roster_transformed_columns
# Out:
#                               Email  Section
# NetID
# wxb12345  woody.barrera_jr@univ.edu        1
# mxl12345   malaika.lambert@univ.edu        2
# txj12345       traci.joyce@univ.edu        1
# jgf12345   john.g.2.flower@univ.edu        3
# smj00936     stacy.johnson@univ.edu        2
# ...                             ...      ...
# pmj37756      paul.johnson@univ.edu        3
# dsl24347      danielle.lee@univ.edu        3
# nxe44872    nicole.edwards@univ.edu        3
# bxr62103      bailey.reyes@univ.edu        2
# jxw53347       joyce.walls@univ.edu        1
#
# [150 rows x 2 columns]

# %% [markdown]
# ### **Load the homework and exam data**

# %%
#load the hw_exam_grades and display first 5 rows
hw_exam_file = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/hw_exam_grades (1).csv')
hw_exam_file.head(5)
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# 1    2019-09-05 08:56:02-07:00          78  ...
# 2    2019-09-05 08:56:02-07:00          66  ...
# 3    2019-09-05 08:56:02-07:00          74  ...
# 4    2019-09-05 08:56:02-07:00          77  ...
#
#    Homework 10 - Submission Time Exam 1  Exam 1 - Max Points  \
# 0      2019-10-31 08:56:02-07:00     79                  100
# 1      2019-10-31 08:56:02-07:00     65                  100
# 2      2019-10-31 08:56:02-07:00     65                  100
# 3      2019-10-31 08:56:02-07:00     97                  100
# 4      2019-10-31 08:56:02-07:00     68                  100
#
#     Exam 1 - Submission Time Exam 2  Exam 2 - Max Points  \
# 0  2019-10-08 12:30:07-07:00     63                  100
# 1  2019-10-08 12:30:07-07:00     63                  100
# 2  2019-10-08 12:30:07-07:00     78                  100
# 3  2019-10-08 12:30:07-07:00     97                  100
# 4  2019-10-08 12:30:07-07:00     95                  100
#
#     Exam 2 - Submission Time Exam 3  Exam 3 - Max Points  \
# 0  2019-11-08 12:30:07-07:00     68                  100
# 1  2019-11-08 12:30:07-07:00     90                  100
# 2  2019-11-08 12:30:07-07:00     83                  100
# 3  2019-11-08 12:30:07-07:00     81                  100
# 4  2019-11-08 12:30:07-07:00     88                  100
#
#     Exam 3 - Submission Time
# 0  2019-12-08 12:30:07-07:00
# 1  2019-12-08 12:30:07-07:00
# 2  2019-12-08 12:30:07-07:00
# 3  2019-12-08 12:30:07-07:00
# 4  2019-12-08 12:30:07-07:00
#
# [5 rows x 42 columns]

# %% [markdown]
# The data is not cleaned. We also want to do something different to it.
#
# We want the data to be indexed on the basis of SID and remove all the columns which has the word 'Submission' in it using lambda filter.

# %%
#if you attempt to remove the submissional columns without lambda filter, points will be deducted accordingly.
hw_exam_file.set_index('SID', inplace=True)
hw_exam_file_clean = hw_exam_file.loc[:, lambda df: ~df.columns.str.contains('Submission')]
hw_exam_file_clean
# Out:
#          First Name   Last Name  Homework 1  Homework 1 - Max Points  \
# SID
# axl60952      Aaron      Lester        68.0                       80
# amc28428       Adam      Cooper        80.0                       80
# axc64717       Alec       Curry        69.0                       80
# akr14831  Alexander   Rodriguez        50.0                       80
# axd11293      Amber     Daniels        54.0                       80
# ...             ...         ...         ...                      ...
# txw75701     Travis  Washington        64.0                       80
# tbr17292       Troy     Raymond        50.0                       80
# vkb66346   Victoria        Boyd        58.0                       80
# wad63934    William      Daniel        48.0                       80
# wxb12345      Woody     Barrera        55.0                       80
#
#           Homework 2  Homework 2 - Max Points  Homework 3  \
# SID
# axl60952          74                       80          77
# amc28428          78                       80          78
# axc64717          76                       80          66
# akr14831          54                       80          74
# axd11293          57                       80          77
# ...              ...                      ...         ...
# txw75701          67                       80          56
# tbr17292          59                       80          79
# vkb66346          61                       80          75
# wad63934          60                       80          72
# wxb12345          62                       80          73
#
#           Homework 3 - Max Points  Homework 4  Homework 4 - Max Points  ...  \
# SID                                                                     ...
# axl60952                       80          89                      100  ...
# amc28428                       80          87                      100  ...
# axc64717                       80          87                      100  ...
# akr14831                       80          75                      100  ...
# axd11293                       80          95                      100  ...
# ...                           ...         ...                      ...  ...
# txw75701                       80          92                      100  ...
# tbr17292                       80          98                      100  ...
# vkb66346                       80          99                      100  ...
# wad63934                       80          76                      100  ...
# wxb12345                       80          83                      100  ...
#
#           Homework 9  Homework 9 - Max Points  Homework 10  \
# SID
# axl60952          42                       60           41
# amc28428          45                       60           53
# axc64717          58                       60           42
# akr14831          38                       60           47
# axd11293          46                       60           59
# ...              ...                      ...          ...
# txw75701          40                       60           52
# tbr17292          45                       60           49
# vkb66346          40                       60           50
# wad63934          51                       60           36
# wxb12345          45                       60           46
#
#           Homework 10 - Max Points  Exam 1  Exam 1 - Max Points  Exam 2  \
# SID
# axl60952                        60      79                  100      63
# amc28428                        60      65                  100      63
# axc64717                        60      65                  100      78
# akr14831                        60      97                  100      97
# axd11293                        60      68                  100      95
# ...                            ...     ...                  ...     ...
# txw75701                        60      94                  100      74
# tbr17292                        60      91                  100      67
# vkb66346                        60      68                  100      93
# wad63934                        60      84                  100      91
# wxb12345                        60      86                  100      62
#
#           Exam 2 - Max Points  Exam 3  Exam 3 - Max Points
# SID
# axl60952                  100      68                  100
# amc28428                  100      90                  100
# axc64717                  100      83                  100
# akr14831                  100      81                  100
# axd11293                  100      88                  100
# ...                       ...     ...                  ...
# txw75701                  100      68                  100
# tbr17292                  100     100                  100
# vkb66346                  100      69                  100
# wad63934                  100      95                  100
# wxb12345                  100      90                  100
#
# [150 rows x 28 columns]

# %% [markdown]
# ### **Load the Quiz Files**

# %% [markdown]
# Load quiz grades (quiz_1_grades.csv, ..., quiz_5_grades.csv)

# %%
#load all the quizzes now, but i want it the dataframe to be indexed on emails, and return all quizzes corresponding to that email.
#for the expected output of this code, refer to the submissional pdf shared with you in whatsapp group.
quiz_01 = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/quiz_1_grades (1).csv', index_col='Email')
quiz_01.rename(columns={'Grade': 'Quiz 1'}, inplace=True)
quiz_01.drop(['First Name', 'Last Name'], axis=1, inplace=True)
quiz_02 = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/quiz_2_grades.csv', index_col='Email')
quiz_02.rename(columns={'Grade': 'Quiz 2'}, inplace=True)
quiz_02.drop(['First Name', 'Last Name'], axis=1, inplace=True)
quiz_03 = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/quiz_3_grades.csv', index_col='Email')
quiz_03.rename(columns={'Grade': 'Quiz 3'}, inplace=True)
quiz_03.drop(['First Name', 'Last Name'], axis=1, inplace=True)
quiz_04 = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/quiz_4_grades.csv', index_col='Email')
quiz_04.rename(columns={'Grade': 'Quiz 4'}, inplace=True)
quiz_04.drop(['First Name', 'Last Name'], axis=1, inplace=True)
quiz_05 = pd.read_csv('/content/drive/My Drive/Pandas_Mini_Project/quiz_5_grades.csv', index_col='Email')
quiz_05.rename(columns={'Grade': 'Quiz 5'}, inplace=True)
quiz_05.drop(['First Name', 'Last Name'], axis=1, inplace=True)
quiz_05
# Out:
#                           Quiz 5
# Email
# rachel.dennis@univ.edu        11
# courtney.wolf@univ.edu         9
# aaron.lester@univ.edu          8
# ashley.martin@univ.edu        11
# jessica.garza@univ.edu        10
# ...                          ...
# brandy.reilly@univ.edu        10
# douglas.payne@univ.edu         5
# tara.johnson@univ.edu         12
# michelle.lee@univ.edu         10
# scott.cervantes@univ.edu       9
#
# [150 rows x 1 columns]

# %% [markdown]
# Now, join the roster and the hw_exam_grades and store it in a df named '**final_df**' display first 5 rows.

# %%
final_df = pd.merge(roster_transformed_columns, hw_exam_file_clean, left_on='NetID', right_on='SID', how='inner')
final_df.head(5)
# Out:
#                        Email  Section First Name Last Name  Homework 1  \
# 0  woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1   malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2       traci.joyce@univ.edu        1      Traci     Joyce         NaN
# 3   john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4     stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
#
#    Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                       80          62                       80          73
# 1                       80          57                       80          78
# 2                       80          77                       80          58
# 3                       80          52                       80          64
# 4                       80          55                       80          60
#
#    Homework 3 - Max Points  ...  Homework 9  Homework 9 - Max Points  \
# 0                       80  ...          45                       60
# 1                       80  ...          45                       60
# 2                       80  ...          59                       60
# 3                       80  ...          42                       60
# 4                       80  ...          59                       60
#
#    Homework 10  Homework 10 - Max Points  Exam 1  Exam 1 - Max Points  Exam 2  \
# 0           46                        60      86                  100      62
# 1           37                        60      60                  100      91
# 2           53                        60     100                  100      84
# 3           40                        60      72                  100      83
# 4           48                        60      96                  100      80
#
#    Exam 2 - Max Points  Exam 3  Exam 3 - Max Points
# 0                  100      90                  100
# 1                  100      93                  100
# 2                  100      64                  100
# 3                  100      77                  100
# 4                  100      86                  100
#
# [5 rows x 30 columns]

# %% [markdown]
# Also, display quiz **columns** and **indexes** in two seperate code blocks to make sure you get the sense of the data.

# %%
#print("Quiz 01 Columns:", quiz_01.columns)
#print("Quiz 02 Columns:", quiz_02.columns)
#print("Quiz 03 Columns:", quiz_03.columns)
#print("Quiz 04 Columns:", quiz_04.columns)
#print("Quiz 05 Columns:", quiz_05.columns)

# %%
#print("Quiz 01 Indexes:", quiz_01.index)
#print("Quiz 02 Indexes:", quiz_02.index)
#print("Quiz 03 Indexes:", quiz_03.index)
#print("Quiz 04 Indexes:", quiz_04.index)
#print("Quiz 05 Indexes:", quiz_05.index)

# %% [markdown]
# ### **Merging the Grade DataFrame**

# %%
#now merge the final_df and quiz grades, on EMAIL ADDRESS and overwrite it in final_df variable
final_df = final_df.merge(quiz_01, on='Email', how='inner') \
                   .merge(quiz_02, on='Email', how='inner') \
                   .merge(quiz_03, on='Email', how='inner') \
                   .merge(quiz_04, on='Email', how='inner') \
                   .merge(quiz_05, on='Email', how='inner')
#fill empty values with 0 as well
final_df.fillna(0, inplace=True)
final_df.head(5)
# Out:
#                        Email  Section First Name Last Name  Homework 1  \
# 0  woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1   malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2       traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3   john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4     stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
#
#    Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                       80          62                       80          73
# 1                       80          57                       80          78
# 2                       80          77                       80          58
# 3                       80          52                       80          64
# 4                       80          55                       80          60
#
#    Homework 3 - Max Points  ...  Exam 1 - Max Points  Exam 2  \
# 0                       80  ...                  100      62
# 1                       80  ...                  100      91
# 2                       80  ...                  100      84
# 3                       80  ...                  100      83
# 4                       80  ...                  100      80
#
#    Exam 2 - Max Points  Exam 3  Exam 3 - Max Points  Quiz 1  Quiz 2  Quiz 3  \
# 0                  100      90                  100       4      10      11
# 1                  100      93                  100       8      10      10
# 2                  100      64                  100       8       6      14
# 3                  100      77                  100       8       8       8
# 4                  100      86                  100       6      14      11
#
#    Quiz 4  Quiz 5
# 0       7      10
# 1      13       6
# 2       9       4
# 3      13       5
# 4       7       7
#
# [5 rows x 35 columns]

# %% [markdown]
# ### **Calculate Grades with Pandas DataFrame**

# %% [markdown]
# ### Exam Grades

# %% [markdown]
# Now, I want you to calculate the percentage of all 3 exams and then have it display at the end of the final_df

# %%
#to find the percentage:   Exam 1 / Exam 1 max points.
#Hint: you can use fstrings and loops for it
obtained_marks = ['Exam 1', 'Exam 2', 'Exam 3']
total_marks = ['Exam 1 - Max Points', 'Exam 2 - Max Points', 'Exam 3 - Max Points']

for exam, max_points in zip(obtained_marks, total_marks):
    final_df[f'{exam} Score'] = (final_df[exam] / final_df[max_points])

final_df.head()
# Out:
#                        Email  Section First Name Last Name  Homework 1  \
# 0  woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1   malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2       traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3   john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4     stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
#
#    Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                       80          62                       80          73
# 1                       80          57                       80          78
# 2                       80          77                       80          58
# 3                       80          52                       80          64
# 4                       80          55                       80          60
#
#    Homework 3 - Max Points  ...  Exam 3  Exam 3 - Max Points  Quiz 1  Quiz 2  \
# 0                       80  ...      90                  100       4      10
# 1                       80  ...      93                  100       8      10
# 2                       80  ...      64                  100       8       6
# 3                       80  ...      77                  100       8       8
# 4                       80  ...      86                  100       6      14
#
#    Quiz 3  Quiz 4  Quiz 5  Exam 1 Score  Exam 2 Score  Exam 3 Score
# 0      11       7      10          0.86          0.62          0.90
# 1      10      13       6          0.60          0.91          0.93
# 2      14       9       4          1.00          0.84          0.64
# 3       8      13       5          0.72          0.83          0.77
# 4      11       7       7          0.96          0.80          0.86
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Homework Grades

# %% [markdown]
# **Question 1: Identifying Homework Columns**

# %%
#Identify and separate the columns representing homework scores and their respective maximum points.
hw_final_df = final_df.loc[:, lambda df: df.columns.str.contains('Homework')]
hw_final_df
# Out:
#      Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# 0          55.0                       80          62                       80
# 1          63.0                       80          57                       80
# 2           0.0                       80          77                       80
# 3          69.0                       80          52                       80
# 4          74.0                       80          55                       80
# ..          ...                      ...         ...                      ...
# 145        73.0                       80          50                       80
# 146        69.0                       80          51                       80
# 147        62.0                       80          76                       80
# 148        53.0                       80          50                       80
# 149        59.0                       80          77                       80
#
#      Homework 3  Homework 3 - Max Points  Homework 4  Homework 4 - Max Points  \
# 0            73                       80          83                      100
# 1            78                       80          83                      100
# 2            58                       80          91                      100
# 3            64                       80          75                      100
# 4            60                       80          67                      100
# ..          ...                      ...         ...                      ...
# 145          55                       80          65                      100
# 146          70                       80          96                      100
# 147          62                       80          79                      100
# 148          55                       80          97                      100
# 149          61                       80          84                      100
#
#      Homework 5  Homework 5 - Max Points  Homework 6  Homework 6 - Max Points  \
# 0            68                       70          87                       90
# 1            61                       70          88                       90
# 2            66                       70          78                       90
# 3            61                       70          83                       90
# 4            46                       70          85                       90
# ..          ...                      ...         ...                      ...
# 145          47                       70          76                       90
# 146          51                       70          77                       90
# 147          64                       70          74                       90
# 148          57                       70          75                       90
# 149          44                       70          64                       90
#
#      Homework 7  Homework 7 - Max Points  Homework 8  Homework 8 - Max Points  \
# 0            36                       50          43                       70
# 1            42                       50          58                       70
# 2            30                       50          69                       70
# 3            41                       50          43                       70
# 4            43                       50          42                       70
# ..          ...                      ...         ...                      ...
# 145          32                       50          55                       70
# 146          37                       50          52                       70
# 147          37                       50          58                       70
# 148          39                       50          64                       70
# 149          40                       50          45                       70
#
#      Homework 9  Homework 9 - Max Points  Homework 10  \
# 0            45                       60           46
# 1            45                       60           37
# 2            59                       60           53
# 3            42                       60           40
# 4            59                       60           48
# ..          ...                      ...          ...
# 145          40                       60           51
# 146          49                       60           57
# 147          58                       60           51
# 148          41                       60           46
# 149          40                       60           42
#
#      Homework 10 - Max Points
# 0                          60
# 1                          60
# 2                          60
# 3                          60
# 4                          60
# ..                        ...
# 145                        60
# 146                        60
# 147                        60
# 148                        60
# 149                        60
#
# [150 rows x 20 columns]

# %% [markdown]
# **Question 2: Calculating Homework Score by Total Method**

# %%
#Calculate the homework scores by summing the actual scores and dividing by the total possible points.
#hw_obtained = [f'Homework {i}' for i in range(1, 11)]
#hw_total = [f'Homework {i} - Max Points' for i in range(1, 11)]
#final_df.loc[:, 'Homework Score'] = hw_final_df[hw_obtained].sum(axis=1) / hw_final_df[hw_total].sum(axis=1)

homework_scores = final_df.filter(regex=r"^Homework \d\d?$", axis=1)
homework_max_points = final_df.filter(regex=r"^Homework \d\d? -", axis=1)

# %% [markdown]
# **Question 3: Storing Homework Score by Total Method**

# %%
#Add the calculated total homework scores to the DataFrame.
final_df['Homework Score'] = homework_scores.sum(axis=1) / homework_max_points.sum(axis=1)
final_df.head()
# Out:
#                        Email  Section First Name Last Name  Homework 1  \
# 0  woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1   malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2       traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3   john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4     stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
#
#    Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                       80          62                       80          73
# 1                       80          57                       80          78
# 2                       80          77                       80          58
# 3                       80          52                       80          64
# 4                       80          55                       80          60
#
#    Homework 3 - Max Points  ...  Exam 3 - Max Points  Quiz 1  Quiz 2  Quiz 3  \
# 0                       80  ...                  100       4      10      11
# 1                       80  ...                  100       8      10      10
# 2                       80  ...                  100       8       6      14
# 3                       80  ...                  100       8       8       8
# 4                       80  ...                  100       6      14      11
#
#    Quiz 4  Quiz 5  Exam 1 Score  Exam 2 Score  Exam 3 Score  Homework Score
# 0       7      10          0.86          0.62          0.90        0.808108
# 1      13       6          0.60          0.91          0.93        0.827027
# 2       9       4          1.00          0.84          0.64        0.785135
# 3      13       5          0.72          0.83          0.77        0.770270
# 4       7       7          0.96          0.80          0.86        0.782432
#
# [5 rows x 39 columns]

# %% [markdown]
# **Question 4: Preparing Data for Average Calculation**

# %%
#Prepare the maximum points data to align with the actual scores for element-wise division.
hw_max_renamed = homework_max_points.set_axis(homework_scores.columns, axis=1)

# %% [markdown]
# **Question 5: Calculating Homework Score by Average Method**

# %%
#Calculate the average homework scores by dividing each actual score by its corresponding maximum points, summing these ratios, and then dividing by the number of assignments.
average_hw_score = (homework_scores / hw_max_renamed).sum(axis=1)

# %% [markdown]
# **Question 6: Storing Homework Score by Average Method**

# %%
#Add the calculated average homework scores to the DataFrame.
final_df['Average Homework'] = average_hw_score / hw_max_renamed.shape[1]
final_df
# Out:
#                          Email  Section First Name Last Name  Homework 1  \
# 0    woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1     malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2         traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3     john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4       stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
# ..                         ...      ...        ...       ...         ...
# 145      paul.johnson@univ.edu        3       Paul   Johnson        73.0
# 146      danielle.lee@univ.edu        3   Danielle       Lee        69.0
# 147    nicole.edwards@univ.edu        3     Nicole   Edwards        62.0
# 148      bailey.reyes@univ.edu        2     Bailey     Reyes        53.0
# 149       joyce.walls@univ.edu        1      Joyce     Walls        59.0
#
#      Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                         80          62                       80          73
# 1                         80          57                       80          78
# 2                         80          77                       80          58
# 3                         80          52                       80          64
# 4                         80          55                       80          60
# ..                       ...         ...                      ...         ...
# 145                       80          50                       80          55
# 146                       80          51                       80          70
# 147                       80          76                       80          62
# 148                       80          50                       80          55
# 149                       80          77                       80          61
#
#      Homework 3 - Max Points  ...  Quiz 1  Quiz 2  Quiz 3  Quiz 4  Quiz 5  \
# 0                         80  ...       4      10      11       7      10
# 1                         80  ...       8      10      10      13       6
# 2                         80  ...       8       6      14       9       4
# 3                         80  ...       8       8       8      13       5
# 4                         80  ...       6      14      11       7       7
# ..                       ...  ...     ...     ...     ...     ...     ...
# 145                       80  ...      10      14       9      11      10
# 146                       80  ...       7      14      10       5       7
# 147                       80  ...      10      12       9      12      10
# 148                       80  ...      10      15      17       6       7
# 149                       80  ...      10       6       9       7      12
#
#      Exam 1 Score  Exam 2 Score  Exam 3 Score  Homework Score  \
# 0            0.86          0.62          0.90        0.808108
# 1            0.60          0.91          0.93        0.827027
# 2            1.00          0.84          0.64        0.785135
# 3            0.72          0.83          0.77        0.770270
# 4            0.96          0.80          0.86        0.782432
# ..            ...           ...           ...             ...
# 145          0.84          0.80          0.94        0.735135
# 146          0.62          0.70          0.90        0.822973
# 147          0.89          0.63          0.65        0.839189
# 148          0.90          0.72          0.71        0.779730
# 149          0.69          0.73          0.91        0.751351
#
#      Average Homework
# 0            0.799405
# 1            0.818944
# 2            0.785940
# 3            0.765710
# 4            0.787742
# ..                ...
# 145          0.733325
# 146          0.816865
# 147          0.841175
# 148          0.773690
# 149          0.745171
#
# [150 rows x 40 columns]

# %% [markdown]
# **Question 7: Determining the Final Homework Score**

# %%
#Determine the final homework score for each student by taking the maximum value between the total and average methods.
final_df['Total Homework Score'] = final_df[['Homework Score', 'Average Homework']].max(axis=1)
final_df
# Out:
#                          Email  Section First Name Last Name  Homework 1  \
# 0    woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1     malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2         traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3     john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4       stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
# ..                         ...      ...        ...       ...         ...
# 145      paul.johnson@univ.edu        3       Paul   Johnson        73.0
# 146      danielle.lee@univ.edu        3   Danielle       Lee        69.0
# 147    nicole.edwards@univ.edu        3     Nicole   Edwards        62.0
# 148      bailey.reyes@univ.edu        2     Bailey     Reyes        53.0
# 149       joyce.walls@univ.edu        1      Joyce     Walls        59.0
#
#      Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                         80          62                       80          73
# 1                         80          57                       80          78
# 2                         80          77                       80          58
# 3                         80          52                       80          64
# 4                         80          55                       80          60
# ..                       ...         ...                      ...         ...
# 145                       80          50                       80          55
# 146                       80          51                       80          70
# 147                       80          76                       80          62
# 148                       80          50                       80          55
# 149                       80          77                       80          61
#
#      Homework 3 - Max Points  ...  Quiz 2  Quiz 3  Quiz 4  Quiz 5  \
# 0                         80  ...      10      11       7      10
# 1                         80  ...      10      10      13       6
# 2                         80  ...       6      14       9       4
# 3                         80  ...       8       8      13       5
# 4                         80  ...      14      11       7       7
# ..                       ...  ...     ...     ...     ...     ...
# 145                       80  ...      14       9      11      10
# 146                       80  ...      14      10       5       7
# 147                       80  ...      12       9      12      10
# 148                       80  ...      15      17       6       7
# 149                       80  ...       6       9       7      12
#
#      Exam 1 Score  Exam 2 Score  Exam 3 Score  Homework Score  \
# 0            0.86          0.62          0.90        0.808108
# 1            0.60          0.91          0.93        0.827027
# 2            1.00          0.84          0.64        0.785135
# 3            0.72          0.83          0.77        0.770270
# 4            0.96          0.80          0.86        0.782432
# ..            ...           ...           ...             ...
# 145          0.84          0.80          0.94        0.735135
# 146          0.62          0.70          0.90        0.822973
# 147          0.89          0.63          0.65        0.839189
# 148          0.90          0.72          0.71        0.779730
# 149          0.69          0.73          0.91        0.751351
#
#      Average Homework  Total Homework Score
# 0            0.799405              0.808108
# 1            0.818944              0.827027
# 2            0.785940              0.785940
# 3            0.765710              0.770270
# 4            0.787742              0.787742
# ..                ...                   ...
# 145          0.733325              0.735135
# 146          0.816865              0.822973
# 147          0.841175              0.841175
# 148          0.773690              0.779730
# 149          0.745171              0.751351
#
# [150 rows x 41 columns]

# %% [markdown]
# For the output, you may refer to the output refered in the Submission Book.

# %% [markdown]
# ## Quiz Grades
#
# If you used any other method instead of regex to filter the columns, it will result in appropriate points deduction.

# %%
#Filter the columns representing quiz scores using regex.
quiz_scores = final_df.filter(regex=r'^Quiz \d$', axis=1)

# %% [markdown]
# 1. Count the number of quizzes.
# 2. Define the maximum possible points for each quiz.
# 3. Compute the quiz score using the total method.
# 4. Compute the quiz score using the average method.
# 5. Determine the final quiz score by taking the maximum of the two methods.
# 6. Display the DataFrame to check the results

# %%
#Expected Output: The DataFrame should contain an additional column 'Quiz Score' showing the final quiz score for each student, calculated as the maximum value between the total and average methods.
quiz_max_points = quiz_scores.max()

sum_of_quiz_scores = quiz_scores.sum(axis=1)
sum_of_quiz_max = quiz_max_points.sum()
final_df["Total Quizzes"] = sum_of_quiz_scores / sum_of_quiz_max

average_quiz_scores = (quiz_scores / quiz_max_points).sum(axis=1)
final_df["Average Quizzes"] = average_quiz_scores / quiz_scores.shape[1]

final_df["Quiz Score"] = final_df[["Total Quizzes", "Average Quizzes"]].max(axis=1)

final_df
# Out:
#                          Email  Section First Name Last Name  Homework 1  \
# 0    woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1     malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2         traci.joyce@univ.edu        1      Traci     Joyce         0.0
# 3     john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4       stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
# ..                         ...      ...        ...       ...         ...
# 145      paul.johnson@univ.edu        3       Paul   Johnson        73.0
# 146      danielle.lee@univ.edu        3   Danielle       Lee        69.0
# 147    nicole.edwards@univ.edu        3     Nicole   Edwards        62.0
# 148      bailey.reyes@univ.edu        2     Bailey     Reyes        53.0
# 149       joyce.walls@univ.edu        1      Joyce     Walls        59.0
#
#      Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# 0                         80          62                       80          73
# 1                         80          57                       80          78
# 2                         80          77                       80          58
# 3                         80          52                       80          64
# 4                         80          55                       80          60
# ..                       ...         ...                      ...         ...
# 145                       80          50                       80          55
# 146                       80          51                       80          70
# 147                       80          76                       80          62
# 148                       80          50                       80          55
# 149                       80          77                       80          61
#
#      Homework 3 - Max Points  ...  Quiz 5  Exam 1 Score  Exam 2 Score  \
# 0                         80  ...      10          0.86          0.62
# 1                         80  ...       6          0.60          0.91
# 2                         80  ...       4          1.00          0.84
# 3                         80  ...       5          0.72          0.83
# 4                         80  ...       7          0.96          0.80
# ..                       ...  ...     ...           ...           ...
# 145                       80  ...      10          0.84          0.80
# 146                       80  ...       7          0.62          0.70
# 147                       80  ...      10          0.89          0.63
# 148                       80  ...       7          0.90          0.72
# 149                       80  ...      12          0.69          0.73
#
#      Exam 3 Score  Homework Score  Average Homework  Total Homework Score  \
# 0            0.90        0.808108          0.799405              0.808108
# 1            0.93        0.827027          0.818944              0.827027
# 2            0.64        0.785135          0.785940              0.785940
# 3            0.77        0.770270          0.765710              0.770270
# 4            0.86        0.782432          0.787742              0.787742
# ..            ...             ...               ...                   ...
# 145          0.94        0.735135          0.733325              0.735135
# 146          0.90        0.822973          0.816865              0.822973
# 147          0.65        0.839189          0.841175              0.841175
# 148          0.71        0.779730          0.773690              0.779730
# 149          0.91        0.751351          0.745171              0.751351
#
#      Total Quizzes  Average Quizzes  Quiz Score
# 0         0.608696         0.602139    0.608696
# 1         0.681159         0.682149    0.682149
# 2         0.594203         0.585399    0.594203
# 3         0.608696         0.615286    0.615286
# 4         0.652174         0.641836    0.652174
# ..             ...              ...         ...
# 145       0.782609         0.798177    0.798177
# 146       0.623188         0.619682    0.623188
# 147       0.768116         0.785796    0.785796
# 148       0.797101         0.784199    0.797101
# 149       0.637681         0.667701    0.667701
#
# [150 rows x 44 columns]

# %% [markdown]
# ## Group the data to calculate final scores!

# %%
weights = pd.Series(
    {
        "Exam 1 Score": 0.05,
        "Exam 2 Score": 0.10,
        "Exam 3 Score": 0.15,
        "Quiz Score": 0.30,
        "Homework Score": 0.40,
    }
)

# %% [markdown]
# 1. Define the weights for each component.
# 2. Calculate the final score by applying the weights to each component and summing the results.
# 3. Calculate the ceiling score by rounding up the final score multiplied by 100.
# 4. Define a function to convert numeric scores to letter grades based on standard thresholds.
# 5. Map the ceiling scores to letter grades.
# 6. Store the letter grades as a categorical column in the DataFrame.
# 7. Display the final letter grades.

# %%
#For Expected output, refer to the submissional pdf.
final_df['Final Score'] = (final_df[weights.index] * weights).sum(axis=1)
final_df['Ceiling Score'] = np.ceil(final_df['Final Score'] * 100)

# %%
grades = {
    90: "A",
    80: "B",
    70: "C",
    60: "D",
    0: "F",
}

def grading_value(values):
  for key, letter in grades.items():
    if values >= key:
      return letter

# %%
grading = final_df['Ceiling Score'].map(grading_value)
final_df['Final Score'] = pd.Categorical(grading, categories=grades.values(), ordered=True)
final_df['NetID'] = NetID
final_df
transformed_final_df = final_df[['NetID', 'First Name', 'Last Name', 'Email', 'Ceiling Score', 'Final Score']]
transformed_final_df
# Out:
#         NetID First Name Last Name                      Email  Ceiling Score  \
# 0    wxb12345      Woody   Barrera  woody.barrera_jr@univ.edu           75.0
# 1    mxl12345    Malaika   Lambert   malaika.lambert@univ.edu           80.0
# 2    txj12345      Traci     Joyce       traci.joyce@univ.edu           73.0
# 3    jgf12345      Gregg    Flower   john.g.2.flower@univ.edu           73.0
# 4    smj00936      Stacy   Johnson     stacy.johnson@univ.edu           77.0
# ..        ...        ...       ...                        ...            ...
# 145  pmj37756       Paul   Johnson      paul.johnson@univ.edu           80.0
# 146  dsl24347   Danielle       Lee      danielle.lee@univ.edu           76.0
# 147  nxe44872     Nicole   Edwards    nicole.edwards@univ.edu           78.0
# 148  bxr62103     Bailey     Reyes      bailey.reyes@univ.edu           78.0
# 149  jxw53347      Joyce     Walls       joyce.walls@univ.edu           75.0
#
#     Final Score
# 0             C
# 1             B
# 2             C
# 3             C
# 4             C
# ..          ...
# 145           B
# 146           C
# 147           C
# 148           C
# 149           C
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Now, you have to write the data back to CSV.

# %%
#For the expected output, refer to the submissional pdf.
transformed_final_df.to_csv("final_data.csv", index=False)
